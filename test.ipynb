# %%
import pandas as pd
df = pd.read_csv('data.csv', encoding = 'latin1')

# %%
df.dtypes
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

df["Revenue"] = df["Quantity"] * df["UnitPrice"]
df = df[df['Quantity'] > 0]

# %%
df['Quantity'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
monthly = df.set_index("InvoiceDate").resample("M")["Revenue"].sum()
monthly
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_27484\2959410723.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = df.set_index("InvoiceDate").resample("M")["Revenue"].sum()
# InvoiceDate
# 2010-12-31     823746.140
# 2011-01-31     691364.560
# 2011-02-28     523631.890
# 2011-03-31     717639.360
# 2011-04-30     537808.621
# 2011-05-31     770536.020
# 2011-06-30     761739.900
# 2011-07-31     719221.191
# 2011-08-31     737014.260
# 2011-09-30    1058590.172
# 2011-10-31    1154979.300
# 2011-11-30    1509496.330
# 2011-12-31     638792.680
# Freq: ME, Name: Revenue, dtype: float64

# %%
growth = monthly.pct_change() * 100
growth
# Out:
# InvoiceDate
# 2010-12-31          NaN
# 2011-01-31   -16.070677
# 2011-02-28   -24.261103
# 2011-03-31    37.050354
# 2011-04-30   -25.058650
# 2011-05-31    43.273274
# 2011-06-30    -1.141559
# 2011-07-31    -5.581788
# 2011-08-31     2.473936
# 2011-09-30    43.632251
# 2011-10-31     9.105424
# 2011-11-30    30.694665
# 2011-12-31   -57.681733
# Freq: ME, Name: Revenue, dtype: float64
